# %% [markdown]
# <a href="https://colab.research.google.com/github/DeguShi/AI-notebooks/blob/main/mod_2_print__algorithm_Astar_mod.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atividade 1:

# %%
import pandas as pd
import numpy as np

try: import folium
except:
    # !pip install folium
from folium.plugins import MarkerCluster

from math import sin, cos, sqrt, atan2, radians
from tqdm import tqdm
import heapq
import time
import pickle
from sklearn.metrics.pairwise import haversine_distances
from IPython.display import display
import os


if not os.path.exists('alagamentos.xlsx'): # baixando os dados só na primeira run, achei melhor assim
    # !gdown 1K0tu3E-kcu7ikQcyNnKixjCY8vSjvxgl -O alagamentos.xlsx

print("Bibliotecas e dataset importados!")

# Carrego todo dadaset primeiro e separo os dados em um jeito que fica mais facil extrair as informações depois

df_base = pd.read_excel('alagamentos.xlsx')
df_base[['lat', 'lon']] = df_base['localidade'].str.split(",", expand=True).astype(float)
df_base['cidade'] = df_base['descricao']


df_base
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1K0tu3E-kcu7ikQcyNnKixjCY8vSjvxgl
# To: /content/alagamentos.xlsx
# 100% 381k/381k [00:00<00:00, 87.3MB/s]
# Bibliotecas e dataset importados!
#                                                descricao  \
# 0      Chuvas deixam cidade de SP em estado de atençã...
# 1      Chuva em SP deixa linha de trem e trecho de ro...
# 2      Cidade de São Paulo entra em estado de atenção...
# 3      Chuva em SP causa queda de árvores, alagamento...
# 4      São Paulo registra 18ª morte por causa das chu...
# ...                                                  ...
# 11939  Chuva forte e ventos intensos trazem alerta ao...
# 11940  Afetados por chuvas receberão auxílio nas próx...
# 11941  Fortes chuvas causam alagamentos em Bom Jesus ...
# 11942  BR-101 é interditada nos dois sentidos em Camp...
# 11943  Forte chuva deixa distrito de Raposo em estado...
#
#                   localidade        lat        lon  \
# 0      -23.567387,-46.570383 -23.567387 -46.570383
# 1      -23.567387,-46.570383 -23.567387 -46.570383
# 2      -23.567387,-46.570383 -23.567387 -46.570383
# 3      -23.567387,-46.570383 -23.567387 -46.570383
# 4      -23.567387,-46.570383 -23.567387 -46.570383
# ...                      ...        ...        ...
# 11939  -21.210591,-41.886203 -21.210591 -41.886203
# 11940  -21.210591,-41.886203 -21.210591 -41.886203
# 11941  -21.210591,-41.886203 -21.210591 -41.886203
# 11942  -21.210591,-41.886203 -21.210591 -41.886203
# 11943  -21.210591,-41.886203 -21.210591 -41.886203
#
#                                                   cidade
# 0      Chuvas deixam cidade de SP em estado de atençã...
# 1      Chuva em SP deixa linha de trem e trecho de ro...
# 2      Cidade de São Paulo entra em estado de atenção...
# 3      Chuva em SP causa queda de árvores, alagamento...
# 4      São Paulo registra 18ª morte por causa das chu...
# ...                                                  ...
# 11939  Chuva forte e ventos intensos trazem alerta ao...
# 11940  Afetados por chuvas receberão auxílio nas próx...
# 11941  Fortes chuvas causam alagamentos em Bom Jesus ...
# 11942  BR-101 é interditada nos dois sentidos em Camp...
# 11943  Forte chuva deixa distrito de Raposo em estado...
#
# [11944 rows x 5 columns]

# %% [markdown]
# # Preciso add exemplicação para a haver depois

# %% [markdown]
# ![Screenshot 2025-05-27 at 14.19.30.png](data:image/png;base64,...)

# %%
# Funcao haversine para calcular a distancia entre cidades

def haversine(lat1, lon1, lat2, lon2):
    R = 6371
    dLat = radians(lat2 - lat1)
    dLon = radians(lon2 - lon1)
    lat1_rad = radians(lat1)
    lat2_rad = radians(lat2)
    a = sin(dLat / 2)**2 + cos(lat1_rad) * cos(lat2_rad) * sin(dLon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

# %%
# Como existem muitas notícias sobre uma mesma coord, vou dar um groupby e trabalhar só informações únicas

df_unicos = df_base.groupby(['lat', 'lon'], as_index=False).first()

# Dados para facilitar testagem entre samples e controle de geração:

AUTONOMIA = 750.0 # distancia que o drone consegue viajar por trecho
RANDOM_SEED = 42
SAMPLE_SIZE = 10000 # eu segui esse tamanho porque estava inicialmente assim no .ipynb da descrição da atividade

unique_sample_size = min(SAMPLE_SIZE, len(df_unicos))
df = df_unicos.sample(unique_sample_size, random_state=RANDOM_SEED).reset_index(drop=True)

# Aqui eu suponho que tenha um jeito inteligente para fazer isso, mas eu optei por fazer esse dicionário manualmente:

capitais_coords_map = {
    'Aracaju':        (-10.907216, -37.048213), 'Belém':          (-1.459845,  -48.487826),
    'Belo Horizonte': (-19.937524, -43.926453), 'Boa Vista':      (2.816682,   -60.670533),
    'Brasília':       (-15.779720, -47.929720), 'Campo Grande':   (-20.448610, -54.629720),
    'Cuiabá':         (-15.598890, -56.094720), 'Curitiba':       (-25.429720, -49.271940),
    'Florianópolis':  (-26.304518,-48.849409), 'Fortaleza':      (-3.731940,  -38.526670),
    'Goiânia':        (-16.680000, -49.255000), 'João Pessoa':    (-7.119440,  -34.863060),
    'Macapá':         (0.038890,   -51.066390), 'Maceió':         (-9.665830,  -35.735280),
    'Manaus':         (-3.118890,  -60.025000), 'Natal':          (-5.794440,  -35.209440),
    'Palmas':         (-10.167500, -48.331670), 'Porto Alegre':   (-30.033060, -51.230000),
    'Porto Velho':    (-8.761940,  -63.903890), 'Recife':         (-8.054170,  -34.881390),
    'Rio Branco':     (-9.974720,  -67.810000), 'Rio de Janeiro': (-22.871251,-43.775041),
    'Salvador':       (-12.971110, -38.510830), 'São Luís':       (-2.529720,  -44.302780),
    'São Paulo':      (-23.550520, -46.633308), 'Teresina':       (-5.090000,  -42.810000),
    'Vitória':        (-20.319440, -40.337780)
}

# Agora eu defino quais cidades unicas são capitais, isso é relavante tanto para o calculo de rota quanto para representação grafica

nome_cap_para_id = {}
df['is_cap'] = False


cap_dic = pd.DataFrame(capitais_coords_map.items(), columns=['NomeCap', 'Coords'])
cap_dic[['cap_lat', 'cap_lon']] = pd.DataFrame(cap_dic['Coords'].tolist(), index=cap_dic.index)


# agora eu mapeio os dados do df de modo a categorizar as capitais com o dicionário que fiz acima:

for index, cap_linha in cap_dic.iterrows():
  distancias = df.apply(lambda linha: haversine(cap_linha['cap_lat'], cap_linha['cap_lon'], linha['lat'], linha['lon']), axis=1)
  index_no_df = distancias.idxmin()
  if index_no_df not in nome_cap_para_id.values() and distancias.min() <10:
    nome_cap_para_id[cap_linha['NomeCap']] = index_no_df
    df.loc[index_no_df, 'is_cap'] = True
    df.loc[index_no_df, 'cidade'] = cap_linha['NomeCap']

# Só informa os dados classificados até então

print(f"\n{len(df)} cidades unicas (Sample {unique_sample_size}, Seed {RANDOM_SEED}).")
print(f"{len(nome_cap_para_id)} capitais identificadas na amostra e mapeadas:")
print(nome_cap_para_id)

# Agora crio um set para as capitais (para verificar dados mais rapido) e um pkl para cache de distacias min até um capital depois

id_set_cap = set(nome_cap_para_id.values())

dist_min_cap_file = f'dist_min_capital_s{len(df)}_r{RANDOM_SEED}.pkl'
if os.path.exists(dist_min_cap_file): os.remove(dist_min_cap_file)

df
# Out:
# 318 cidades unicas (Sample 318, Seed 42).
# 26 capitais identificadas na amostra e mapeadas:
# {'Aracaju': 296, 'Belém': 68, 'Belo Horizonte': 36, 'Boa Vista': 311, 'Brasília': 257, 'Cuiabá': 309, 'Curitiba': 144, 'Florianópolis': 167, 'Fortaleza': 87, 'Goiânia': 142, 'João Pessoa': 146, 'Macapá': 291, 'Maceió': 175, 'Manaus': 34, 'Natal': 164, 'Palmas': 73, 'Porto Alegre': 224, 'Porto Velho': 194, 'Recife': 297, 'Rio Branco': 180, 'Rio de Janeiro': 267, 'Salvador': 178, 'São Luís': 75, 'São Paulo': 81, 'Teresina': 240, 'Vitória': 32}
#            lat        lon                                          descricao  \
# 0   -23.468506 -46.531084  Concessionária de carros de luxo fica completa...
# 1    -5.352606 -49.142025  Enchentes em 3 cidades do Pará deixam famílias...
# 2   -26.991819 -48.634617  Veja imagens dos alagamentos em Balneário Camb...
# 3    -7.828372 -34.910583  Prefeita de Igarassu fala sobre situação do mu...
# 4   -29.759823 -57.081825  Prejuízos e alagamento: funcionários de instit...
# ..         ...        ...                                                ...
# 313 -19.224346 -42.605661  Abrigos provisórios para moradores de áreas de...
# 314 -23.499323 -47.457853  FOTOS: Chuva causa alagamentos e transtornos e...
# 315 -22.858395 -47.221097  Chuva intensa em Hortolândia causa alagamentos...
# 316  -6.214964 -36.688662  Temporal deixa Baixada Santista, SP, debaixo d...
# 317 -22.880765 -42.020075  Chuva causa alagamento em alguns pontos de Cab...
#
#                 localidade                                             cidade  \
# 0    -23.468506,-46.531084  Concessionária de carros de luxo fica completa...
# 1     -5.352606,-49.142025  Enchentes em 3 cidades do Pará deixam famílias...
# 2    -26.991819,-48.634617  Veja imagens dos alagamentos em Balneário Camb...
# 3     -7.828372,-34.910583  Prefeita de Igarassu fala sobre situação do mu...
# 4    -29.759823,-57.081825  Prejuízos e alagamento: funcionários de instit...
# ..                     ...                                                ...
# 313  -19.224346,-42.605661  Abrigos provisórios para moradores de áreas de...
# 314  -23.499323,-47.457853  FOTOS: Chuva causa alagamentos e transtornos e...
# 315  -22.858395,-47.221097  Chuva intensa em Hortolândia causa alagamentos...
# 316   -6.214964,-36.688662  Temporal deixa Baixada Santista, SP, debaixo d...
# 317  -22.880765,-42.020075  Chuva causa alagamento em alguns pontos de Cab...
#
#      is_cap
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ..      ...
# 313   False
# 314   False
# 315   False
# 316   False
# 317   False
#
# [318 rows x 6 columns]

# %% [markdown]
# # Grafo

# %%
# Agora eu vou começar a preparar os dados para criar um grafo a partir do df

coords_rad = np.radians(df[['lat', 'lon']].values)
matriz_dist_km = haversine_distances(coords_rad, coords_rad)*6371.0

print("Matriz de distâncias pronta.")



graph = {i: [] for i in df.index}

indices_i, indices_j = np.where((matriz_dist_km <= AUTONOMIA) & (matriz_dist_km > 0))

for i, j in zip(indices_i, indices_j):
    dist = matriz_dist_km[i,j]
    graph[df.index[i]].append((df.index[j], dist))

print("Grafo pronto.\n")

# Isso vai me ajudar para quando eu for montar meu  "A*" mais a diante :D

grau_nos = {node_idx: len(v) for node_idx, v in graph.items()}

for i in df.index:
  if i not in graph:
    grau_nos[i] = 0

print("Grau dos nos calculados\n")
# Out:
# Matriz de distâncias pronta.
# Grafo pronto.
#
# Grau dos nos calculados

# %%
# estava achando estranho a dist de RJ e FL ser curta suficiente para existir uma aresta entre elas


idx_rj_df = nome_cap_para_id.get('Rio de Janeiro')
idx_flo_df = nome_cap_para_id.get('Florianópolis')

if idx_rj_df is not None and idx_flo_df is not None:
    print(f"Índice de RJ no df: {idx_rj_df}")
    print(f"Índice de FL no df: {idx_flo_df}")
else:
    print("RJ ou FLO não presntes")



if idx_rj_df is not None and idx_flo_df is not None:
    coords_rj_no_df = df.loc[idx_rj_df, ['lat', 'lon']]
    coords_flo_no_df = df.loc[idx_flo_df, ['lat', 'lon']]
    print(f"Coordenadas de RJ no df: lat={coords_rj_no_df['lat']}, lon={coords_rj_no_df['lon']}")
    print(f"Coordenadas de FL no df: lat={coords_flo_no_df['lat']}, lon={coords_flo_no_df['lon']}")


if idx_rj_df is not None and idx_flo_df is not None:
  distancia_na_matriz = matriz_dist_km[idx_rj_df, idx_flo_df]
  print(f"dist rj-fl direto da matriz_dist_km: {distancia_na_matriz:.10f} km")


if idx_rj_df is not None and idx_flo_df is not None:
  # Com sua função haversine
  dist_manual_com_coords_df = haversine(coords_rj_no_df['lat'], coords_rj_no_df['lon'],
                                        coords_flo_no_df['lat'], coords_flo_no_df['lon'])
  print(f"dist com a minha haversine: {dist_manual_com_coords_df:.10f} km")

  # Com sklearn
  coords_rj_df_rad = np.radians(np.array([[coords_rj_no_df['lat'], coords_rj_no_df['lon']]]))
  coords_flo_df_rad = np.radians(np.array([[coords_flo_no_df['lat'], coords_flo_no_df['lon']]]))
  dist_sklearn_com_coords_df = haversine_distances(coords_rj_df_rad, coords_flo_df_rad)[0][0] * 6371.0
  print(f"dist com a haversine_dist printa da sk: {dist_sklearn_com_coords_df:.10f} km")
# Out:
# Índice de RJ no df: 267
# Índice de FL no df: 167
# Coordenadas de RJ no df: lat=-22.871251, lon=-43.775041
# Coordenadas de FL no df: lat=-26.304518, lon=-48.849409
# dist rj-fl direto da matriz_dist_km: 639.4026807773 km
# dist com a minha haversine: 639.4026807773 km
# dist com a haversine_dist printa da sk: 639.4026807773 km

# %%
# Algumas definições para calcular a profundidade de busca:

# Eu defini meio que arbitrariamente durante meus testes o que eu considerava uma celula em regiao densa e uma celula em regiao esparsa
# isso é fundamental para eu conseguir variar minha profundidade de busca de maneira otimizada
# para cada nó depois. As cidades escolhidas foram SP e POA porque durante minhas testagens, eu achava 211 cidades na rota partindo de SP
# e somente 190 cidades partindo de POA, isso não fazia sentido para mim, pois se eu chego em POA a partir de SP e encontro 211, o contrário
# deveria ser verdade também. Eu conclui que o problema provavelmente é o fato que a profundidade alta no final da busca consume muito poder
# computacional e memória em geral, pois eu fico guardando muita informação nas minhas iteracoes, para resolver isso eu testei POA com profundidade
# maior e cheguei nas 211 cidades que eu queria, isso abriu meus olhos para uma maneira de otimizar a busca.

idx_sp = nome_cap_para_id.get('São Paulo', -1)
idx_poa = nome_cap_para_id.get('Porto Alegre', -1)

grau_sp = grau_nos.get(idx_sp, -1) if idx_sp != -1 else -1
grau_poa = grau_nos.get(idx_poa, -1) if idx_poa != -1 else -1

# Valores que obtive enquanto testava profundidades fixas manualmente

DEPTH_SP = 5
DEPTH_POA = 20

MIN_OPT_DEPTH = 3
MAX_OPT_DEPTH = 30


print("Referências para profundidade otimizada:")
if grau_sp != -1: print(f"São Paulo: Grau = {grau_sp}, prof: {DEPTH_SP}")
else: print(f"São Paulo não encontrada para referência de grau.")
if grau_poa != -1: print(f"Porto Alegre: Grau = {grau_poa}, prof: {DEPTH_POA}")
else: print(f"Porto Alegre não encontrada para referência de grau.")
# Out:
# Referências para profundidade otimizada:
# São Paulo: Grau = 175, prof: 5
# Porto Alegre: Grau = 48, prof: 20

# %%
# Funcao para calculo da profundidade de fato:

def calcular_profundidade_opt(cur_grau, g_sp, dp_sp, g_poa, dp_poa, min_dp, max_dp):

  # Se o sample tiver algum problema com as referencias que escolhi:

  if g_sp == -1 or g_poa ==  -1 or g_sp == g_poa:
    return (min_dp+max_dp)//2 # usa uma média para trabalhar

  # A ideia em si é simples, eu queria que um no em uma região de alta densidade tivesse profundidade baixa
  # e o contrário também fosse verdade. Sendo assim:

  m = (dp_poa-dp_sp)/(g_poa-g_sp)

  c = dp_sp-m*g_sp

  dp_calculada = m*cur_grau+c

  dp_final = int(round(np.clip(dp_calculada, min_dp, max_dp)))

  return dp_final


print("Calculo de graus e profundidade otimizada prontos.")
# Out:
# Calculo de graus e profundidade otimizada prontos.

# %%
# Agora eu faço as funcoes que vou usar para pre calcular os menores caminhos:

def dijkstra_menor_caminho(g_dic, start_id):
  id_nos_df = list(df.index)
  open_set = [(0, start_id)]
  heapq.heapify(open_set)

  g_score = {idx: float('inf') for idx in id_nos_df}

  if start_id in g_score: g_score[start_id] = 0
  else: return {idx: float('inf') for idx in id_nos_df}

  while open_set:
    cur_g, cur = heapq.heappop(open_set)

    if cur_g > g_score.get(cur, float('inf')): continue

    for v, d in g_dic.get(cur, []):
      if v not in g_score: continue
      temp_g = cur_g + d
      if temp_g < g_score[v]:
        g_score[v] = temp_g
        heapq.heappush(open_set, (temp_g, v))
  return g_score

print("Dijkstra feito.")



def pre_calcular_dist_to_capital(g_dic, id_cap_p_set, nos_df, filename):
  print("Pré calculando distancias para capitais...")

  dist_todas_cap = {}
  for id_cap in tqdm(id_cap_p_set, desc="calculando dijkstra para as cap"):
    dist_da_cap = dijkstra_menor_caminho(g_dic, id_cap)
    dist_todas_cap[id_cap] = dist_da_cap

  dist_min_cap_dic = {idx: float('inf') for idx in nos_df.index}
  for id_no in tqdm(nos_df.index, desc="calculando menor dist"):
    min_dist = float('inf')


    for id_cap in id_cap_p_set:
      dist = dist_todas_cap[id_cap].get(id_no, float('inf'))
      if dist < min_dist: min_dist = dist

    dist_min_cap_dic[id_no] = min_dist

  # salva essas distancias durante a exec para não precisar repetir no mesmo sample
  with open(filename, 'wb')as f: pickle.dump(dist_min_cap_dic, f)
  print(f"Funcao de pre calculo pronta e salva em '{filename}'.")

  return dist_min_cap_dic


#salva tudo
dist_min_cap_filename_global = f'dist_min_capital_s{len(df)}_r{RANDOM_SEED}.pkl'


if not id_set_cap:
    print("Deu algum erro na classificacao de cap, no id_set não tem nada.")
    dist_min_cap = {idx: float('inf') for idx in df.index}
else:
    try:
        with open(dist_min_cap_filename_global, 'rb') as f: dist_min_cap = pickle.load(f)
        if len(dist_min_cap) != len(df):
             dist_min_cap = pre_calcular_dist_to_capital(graph, id_set_cap, df, dist_min_cap_filename_global)
    except FileNotFoundError:
        dist_min_cap = pre_calcular_dist_to_capital(graph, id_set_cap, df, dist_min_cap_filename_global)
print("Distâncias mínimas às capitais prontas.")
# Out:
# Dijkstra feito.
# Pré calculando distancias para capitais...
# calculando dijkstra para as cap: 100%|██████████| 26/26 [00:00<00:00, 56.77it/s]
# calculando menor dist: 100%|██████████| 318/318 [00:00<00:00, 80669.45it/s]
# Funcao de pre calculo pronta e salva em 'dist_min_capital_s318_r42.pkl'.
# Distâncias mínimas às capitais prontas.

# %% [markdown]
# # Heurística para maximizar

# %%
R_SCAN = 100

# pre computa para cada cidade (nao cap), uma lista de outras cidades dentro do raio informado na variavel R_SCAN
# vai servir para informar a heuristica dos clusters de cidades proximas

def pre_calculate_local_density_info(df_nodes, R_scan_param, id_cap_set_param):

    print(f"Pré-calculando densidade local com raio de {R_scan_param} km...")
    local_density_map = {}

    # Filtra apenas os índices das cidades não-capitais
    id_cities_nao_cap = [idx for idx in df_nodes.index if idx not in id_cap_set_param]
    # Converte as coordenadas das cidades não-capitais para radianos para haversine_distances
    rad_cities_nao_cap = np.radians(df_nodes.loc[id_cities_nao_cap, ['lat', 'lon']].values)

    if len(id_cities_nao_cap) > 0:
        # Calcula a matriz de distâncias entre TODAS as cidades não-capitais
        dist_nao_cap = haversine_distances(rad_cities_nao_cap, rad_cities_nao_cap) * 6371.0

        # Mapeia o índice original do DataFrame para a posição na lista `id_cities_nao_cap`
        original_idx_to_pos = {idx: i for i, idx in enumerate(id_cities_nao_cap)}

        for i, no_id_i in tqdm(enumerate(id_cities_nao_cap), total=len(id_cities_nao_cap), desc="Calculando vizinhos locais"):
            nos_perto = []
            # Itera sobre todas as outras cidades não-capitais
            for j, no_id_j in enumerate(id_cities_nao_cap):
                if i != j: # Garante que não estamos comparando a cidade consigo mesma
                    # Usa a matriz de distâncias pré-calculada
                    dist = dist_nao_cap[i, j]
                    if dist <= R_scan_param:
                        nos_perto.append(no_id_j)
            local_density_map[no_id_i] = nos_perto
    else:
        print("Nenhuma cidade não-capital encontrada para análise de densidade local.")

    print("Densidade local pré-calculada.")
    return local_density_map

# Chame a função para popular o mapa de densidade local
local_density_map_global = pre_calculate_local_density_info(df, R_SCAN, id_set_cap)
# Out:
# Pré-calculando densidade local com raio de 100 km...
# Calculando vizinhos locais: 100%|██████████| 292/292 [00:00<00:00, 14629.14it/s]
# Densidade local pré-calculada.

# %% [markdown]
# Eu tive que mudar bastante essa função conforme eu testava, pois não é intuitivo como usar tantos parâmetros e saber que o resultado disso realmente
# importa.
#
# Em geral essa heurística busca estimar a quantidade de cidades que o drone ainda poderia visitar (não capitais) a partir de cur_city e cur_v_fset.
#
# O jeito que essa heurística funciona é uma mescla entre o uso de um algoritmo ganhancioso e registro de memoria em "caches" (para otimização)

# %%
cache_heu = {}
DENSITY_WEIGHT = 7.0

def max_path_heu(cur_city, cur_v_set, gf_map, dist_min_cap_dic, max_auto_val, no_df_dic, max_dp_calculada, local_density_map):
    cache_key = (cur_city, cur_v_set)
    if cache_key in cache_heu:
        return cache_heu[cache_key]

    h_value = 0
    sim_cur = cur_city
    sim_v_set = set(cur_v_set)
    sim_cur_dp = 0

    while sim_cur_dp < max_dp_calculada:
        temp_candidates = []

        for v, d in gf_map.get(sim_cur, []):
            if v not in sim_v_set and not no_df_dic.loc[v, 'is_cap']:
                potential_cities_nearby = 0
                if v in local_density_map:
                        for nearby_node_id in local_density_map.get(v, []):
                                if nearby_node_id not in sim_v_set:
                                        potential_cities_nearby += 1

                combined_score = d - (DENSITY_WEIGHT * potential_cities_nearby)
                temp_candidates.append((combined_score, d, v))

        if not temp_candidates:
            break

        temp_candidates.sort()
        best_score, best_dist, best_v = temp_candidates[0]

        sim_cur = best_v
        sim_v_set.add(best_v)
        h_value += 1
        sim_cur_dp += 1

    cache_heu[cache_key] = h_value
    return h_value

print("Funcao heuristica com cache e densidade adaptada pronta para uso.")
# Out:
# Funcao heuristica com cache e densidade adaptada pronta para uso.

# %% [markdown]
# #A* de fato:

# %%
def a_star_max_heu(gf_map, start_no_id, no_cap_set, no_df_map, max_auto_val, dist_min_cap_map, graus_map, g_sp, dp_sp, g_poa, dp_poa, min_dp, max_dp, max_time_sim=300, max_it_sem_achar_nada=30000, local_density_map=None):
    start_time = time.time()
    cache_heu.clear()

    def heu_aux(id_city,v_set):
        cur_grau = graus_map.get(id_city, 0)
        dp_nessa_call = calcular_profundidade_opt(cur_grau, g_sp, dp_sp, g_poa, dp_poa, min_dp, max_dp)
        return max_path_heu(id_city, v_set, gf_map, dist_min_cap_map, max_auto_val, no_df_map, max_dp_calculada=dp_nessa_call, local_density_map=local_density_map)

    start_comb = max_auto_val
    start_v_fset = frozenset([start_no_id])
    start_g = len(start_v_fset)

    start_no_grau = graus_map.get(start_no_id, 0)
    start_no_dp = calcular_profundidade_opt(start_no_grau, g_sp, dp_sp, g_poa, dp_poa, min_dp, max_dp)

    start_h = max_path_heu(start_no_id, start_v_fset, gf_map, dist_min_cap_map,max_auto_val, no_df_map, max_dp_calculada=start_no_dp, local_density_map=local_density_map)
    start_f = start_g + start_h

    no_cnt = 0
    open_set = []

    dado_ini_no = (start_no_id, start_comb, start_v_fset, [start_no_id], [start_comb])
    heapq.heappush(open_set, (-start_f, -start_g, no_cnt, dado_ini_no))


    pontos_conhecidos = {}
    pontos_conhecidos[(start_no_id, start_v_fset)] = start_comb

    best_g_detodos = 0
    best_path_detodos = []
    best_comb_detodos = []

    iter_count = 0
    it_sem_achar_nada = 0
    parada_por_limite = False

    print("Iniciando busca A*...")
    print(f"==> Profundidade para nó inicial ({no_df_map.loc[start_no_id, 'cidade']}, grau {start_no_grau}): {start_no_dp}")
    print("------ Número de cidades visitadas na melhor rota até agora: ------")

    while open_set:
        current_time_exec = time.time()
        if current_time_exec - start_time > max_time_sim:
            print(f"Tempo limite de {max_time_sim}s atingido.")
            parada_por_limite = True
            break

        iter_count += 1
        it_sem_achar_nada += 1

        if it_sem_achar_nada >= max_it_sem_achar_nada:
            print(f"\nCritério de parada alcançado: nenhuma rota nova foi encontrada por {max_it_sem_achar_nada} iterações.")
            parada_por_limite = True
            break

        if iter_count % 10000 == 0:
            cache_size = len(cache_heu)
            # Obter cur_city do último melhor estado ou do início para o log
            log_cur_city_idx = best_path_detodos[-1] if best_path_detodos else start_no_id
            cur_city_gr = graus_map.get(log_cur_city_idx, 0)
            call_dp = calcular_profundidade_opt(cur_city_gr, g_sp, dp_sp, g_poa, dp_poa, min_dp, max_dp)
            print(f"Iter: {iter_count}, Melhor rota: {best_g_detodos},"
                  f"T: {current_time_exec - start_time:.1f}s, "
                  f"Profundidade para nó g={cur_city_gr} (último melhor): {call_dp}, "
                  f"Iters s/ melhora: {it_sem_achar_nada}")

        try:
            _, neg_g_score, _, current_node_tuple = heapq.heappop(open_set)
            # Desempacota o estado, incluindo a lista de níveis de combustível
            (cur_city, cur_comb_at_arrival, cur_v, cur_path_no, cur_path_comb) = current_node_tuple
        except IndexError:
            print("Fila vazia.")
            break

        cur_g_val = -neg_g_score # Número de cidades visitadas

        if cur_g_val > best_g_detodos:
            best_g_detodos = cur_g_val
            best_path_detodos = cur_path_no
            best_comb_detodos = cur_path_comb # Salva a lista de comb por nó

            cur_city_for_log_grau = graus_map.get(cur_city,0)
            adaptive_depth_for_log = calcular_profundidade_opt(cur_city_for_log_grau, g_sp, dp_sp, g_poa, dp_poa, min_dp, max_dp)

            print(f"     | {best_g_detodos:<3} cidades    ===>    "
                  f"[Grau: {cur_city_for_log_grau}, Profundidade: ~{adaptive_depth_for_log}] |")
            it_sem_achar_nada = 0
        fuel_after_refuel = max_auto_val
        if cur_city in no_cap_set and cur_comb_at_arrival < fuel_after_refuel :


            if pontos_conhecidos.get((cur_city, cur_v), -1) < fuel_after_refuel: # Se o comb para sair deste estado era menor que o tanque cheio.
                pontos_conhecidos[(cur_city, cur_v)] = fuel_after_refuel # Agora temos tanque cheio para sair.
                h_val_refuel = heu_aux(cur_city, cur_v)
                f_score_refuel = cur_g_val + h_val_refuel # g_val não muda, só o potencial futuro e o comb.
                no_cnt +=1
                refueled_node_data = (cur_city, fuel_after_refuel, cur_v, cur_path_no, cur_path_comb)
                heapq.heappush(open_set, (-f_score_refuel, -cur_g_val, no_cnt, refueled_node_data))

        for v_city, dist_to_v in gf_map.get(cur_city, []):
            if cur_comb_at_arrival >= dist_to_v:
                comb_no_v = cur_comb_at_arrival - dist_to_v

                dist_to_nearest_cap_from_neighbor = dist_min_cap_map.get(v_city, float('inf'))
                if comb_no_v < dist_to_nearest_cap_from_neighbor:
                    continue

                temp_v_fset = cur_v | {v_city}
                temp_g_val = len(temp_v_fset)
                prev_best_comb_em_v = pontos_conhecidos.get((v_city, temp_v_fset), -1)

                if prev_best_comb_em_v >= comb_no_v:
                    continue

                pontos_conhecidos[(v_city, temp_v_fset)] = comb_no_v

                novo_no_path = cur_path_no + [v_city]
                novo_no_comb = cur_path_comb + [comb_no_v]

                heu_val_p_vizinho = heu_aux(v_city, temp_v_fset)
                f_score_v = temp_g_val + heu_val_p_vizinho

                no_cnt += 1
                neighbor_node_data = (v_city, comb_no_v, temp_v_fset, novo_no_path, novo_no_comb)
                heapq.heappush(open_set, (-f_score_v, -temp_g_val, no_cnt, neighbor_node_data))

    if parada_por_limite and best_path_detodos:
        ultima_cidade_id = best_path_detodos[-1]

        print("-" * 50)
        print("Verificando rota final devido à parada por limite...")

        if ultima_cidade_id in no_cap_set:
            print("OK: A última cidade da melhor rota já é uma capital.")
        else:
            print(f"Aviso: A última cidade ({no_df_map.loc[ultima_cidade_id, 'cidade']}) não é uma capital.")
            print("Calculando rota de retorno para a capital vizinha mais próxima...")

            combustivel_na_ultima_cidade = best_comb_detodos[-1]
            capital_mais_proxima_id = None
            menor_distancia_para_capital = float('inf')

            # Procura a capital mais próxima entre os vizinhos diretos
            for vizinho_id, dist in gf_map.get(ultima_cidade_id, []):
                if vizinho_id in no_cap_set and dist < menor_distancia_para_capital:
                    menor_distancia_para_capital = dist
                    capital_mais_proxima_id = vizinho_id

            if capital_mais_proxima_id and combustivel_na_ultima_cidade >= menor_distancia_para_capital:
                # Adiciona o trecho final para a capital
                best_path_detodos.append(capital_mais_proxima_id)
                combustivel_final = combustivel_na_ultima_cidade - menor_distancia_para_capital
                best_comb_detodos.append(combustivel_final)

                # Atualiza a contagem de cidades visitadas (usando set para não contar duplicado)
                best_g_detodos = len(set(best_path_detodos))

                print(f"SUCESSO: Rota estendida para a capital '{no_df_map.loc[capital_mais_proxima_id, 'cidade']}'.")
                print(f"Combustível final: {combustivel_final:.2f}L")
            else:
                print("FALHA: Não foi possível estender a rota (sem combustível ou nenhuma capital vizinha encontrada).")
        print("-" * 50)


    return best_path_detodos, best_g_detodos, best_comb_detodos

# %%
capital_de_partida_nome = 'São Paulo'
TEMPO_LIMITE_GLOBAL_A_STAR = 300

rota_global_final = []
cidades_global_final_count = 0
fuel_levels_raw_from_astar = []

if capital_de_partida_nome not in nome_cap_para_id:
    print(f"Erro: Capital '{capital_de_partida_nome}' não no mapeamento 'nome_cap_para_id'.")
elif 'dist_min_cap' not in locals():
    print("Erro: 'dist_min_cap' não calculado.")
elif idx_sp == -1 or idx_poa == -1 or grau_sp == -1 or grau_poa == -1:
    print("Erro: São Paulo ou Porto Alegre não encontrados para referências de grau/profundidade.")
else:
    start_node_idx_global = nome_cap_para_id[capital_de_partida_nome]

    print(f"\n------Iniciando busca A* a partir de: {capital_de_partida_nome}")
    print(f"------Tempo limite: {TEMPO_LIMITE_GLOBAL_A_STAR}s.")
    print(f"------Referências de profundidade: SP (grau {grau_sp}, target {DEPTH_SP}), POA (grau {grau_poa}, target {DEPTH_POA})")
    print(f"------Limites de profundidade da heurística: min={MIN_OPT_DEPTH}, max={MAX_OPT_DEPTH}")

    rota_global_final, cidades_global_final_count, fuel_levels_raw_from_astar = a_star_max_heu(
        gf_map=graph,
        start_no_id=start_node_idx_global,
        no_cap_set=id_set_cap,
        no_df_map=df,
        max_auto_val=AUTONOMIA,
        dist_min_cap_map=dist_min_cap,
        graus_map=grau_nos,
        g_sp=grau_sp, dp_sp=DEPTH_SP,
        g_poa=grau_poa, dp_poa=DEPTH_POA,
        min_dp=MIN_OPT_DEPTH, max_dp=MAX_OPT_DEPTH,
        max_time_sim=TEMPO_LIMITE_GLOBAL_A_STAR,
        max_it_sem_achar_nada=30000,
        local_density_map=local_density_map_global
    )

print("\n---Busca A* Concluída ---")
print(f"Capital Inicial: {capital_de_partida_nome}")
print(f"Número Total de Cidades ÚNICAS Visitadas (g*): {cidades_global_final_count}")

distancia_total_missao = 0
if rota_global_final and len(rota_global_final) > 1:
    for i in range(len(rota_global_final)-1):
        idx1, idx2 = rota_global_final[i], rota_global_final[i+1]
        edge_found = False
        dist_edge = 0
        if idx1 in graph:
            for neighbor, dist_val in graph.get(idx1, []):
                if neighbor == idx2:
                    dist_edge = dist_val
                    edge_found = True
                    break
        if edge_found:
            distancia_total_missao += dist_edge
        elif idx1 in df.index and idx2 in df.index:
             distancia_total_missao += haversine(df.loc[idx1,'lat'], df.loc[idx1,'lon'], df.loc[idx2,'lat'], df.loc[idx2,'lon'])

print(f"Distância Total Percorrida na Missão: {distancia_total_missao:.2f} km")

indices_de_parada_em_capital_na_rota = []
if rota_global_final:
    indices_de_parada_em_capital_na_rota = [
        i for i, node_idx in enumerate(rota_global_final)
        if node_idx in df.index and df.loc[node_idx, 'is_cap']
    ]

paradas_reabastecimento_count = 0
if len(indices_de_parada_em_capital_na_rota) > 1:
    paradas_reabastecimento_count = 0
    for i in range(len(rota_global_final) -1):
        current_node_idx = rota_global_final[i]
        if current_node_idx in df.index and df.loc[current_node_idx, 'is_cap'] and i < len(rota_global_final) - 1 :
            if i > 0 or (i == 0 and rota_global_final[0] != start_node_idx_global):
                 paradas_reabastecimento_count +=1
            elif i == 0 and rota_global_final[0] == start_node_idx_global and len(rota_global_final) > 1 and df.loc[rota_global_final[0], 'is_cap']:
                 pass

    if len(indices_de_parada_em_capital_na_rota) > 0:
        if len(indices_de_parada_em_capital_na_rota) > 1:
            paradas_reabastecimento_count = len(indices_de_parada_em_capital_na_rota) -1

print(f"Total de Paradas para Reabastecimento (capitais intermediárias): {paradas_reabastecimento_count}")

velocidade_kmh = 100
tempo_missao_horas = distancia_total_missao / velocidade_kmh if velocidade_kmh > 0 else 0
print(f"Tempo Total Estimado da Missão: {tempo_missao_horas:.2f} horas")
if 'cache_heu' in locals():
    print(f"Tamanho final do Cache de Heurística: {len(cache_heu)}")
# Out:
# ------Iniciando busca A* a partir de: São Paulo
# ------Tempo limite: 300s.
# ------Referências de profundidade: SP (grau 175, target 5), POA (grau 48, target 20)
# ------Limites de profundidade da heurística: min=3, max=30
# Iniciando busca A*...
# ==> Profundidade para nó inicial (São Paulo, grau 175): 5
# ------ Número de cidades visitadas na melhor rota até agora: ------
#      | 1   cidades    ===>    [Grau: 175, Profundidade: ~5] |
#      | 2   cidades    ===>    [Grau: 102, Profundidade: ~14] |
#      | 3   cidades    ===>    [Grau: 105, Profundidade: ~13] |
#      | 4   cidades    ===>    [Grau: 75, Profundidade: ~17] |
#      | 5   cidades    ===>    [Grau: 80, Profundidade: ~16] |
#      | 6   cidades    ===>    [Grau: 82, Profundidade: ~16] |
#      | 7   cidades    ===>    [Grau: 91, Profundidade: ~15] |
#      | 8   cidades    ===>    [Grau: 94, Profundidade: ~15] |
#      | 9   cidades    ===>    [Grau: 107, Profundidade: ~13] |
#      | 10  cidades    ===>    [Grau: 97, Profundidade: ~14] |
#      | 11  cidades    ===>    [Grau: 122, Profundidade: ~11] |
#      | 12  cidades    ===>    [Grau: 134, Profundidade: ~10] |
#      | 13  cidades    ===>    [Grau: 134, Profundidade: ~10] |
#      | 14  cidades    ===>    [Grau: 136, Profundidade: ~10] |
#      | 15  cidades    ===>    [Grau: 136, Profundidade: ~10] |
#      | 16  cidades    ===>    [Grau: 138, Profundidade: ~9] |
#      | 17  cidades    ===>    [Grau: 156, Profundidade: ~7] |
#      | 18  cidades    ===>    [Grau: 161, Profundidade: ~7] |
#      | 19  cidades    ===>    [Grau: 161, Profundidade: ~7] |
#      | 20  cidades    ===>    [Grau: 164, Profundidade: ~6] |
#      | 21  cidades    ===>    [Grau: 163, Profundidade: ~6] |
#      | 22  cidades    ===>    [Grau: 164, Profundidade: ~6] |
#      | 23  cidades    ===>    [Grau: 166, Profundidade: ~6] |
#      | 24  cidades    ===>    [Grau: 135, Profundidade: ~10] |
#      | 25  cidades    ===>    [Grau: 140, Profundidade: ~9] |
#      | 26  cidades    ===>    [Grau: 142, Profundidade: ~9] |
#      | 27  cidades    ===>    [Grau: 138, Profundidade: ~9] |
#      | 28  cidades    ===>    [Grau: 152, Profundidade: ~8] |
#      | 29  cidades    ===>    [Grau: 157, Profundidade: ~7] |
#      | 30  cidades    ===>    [Grau: 142, Profundidade: ~9] |
#      | 31  cidades    ===>    [Grau: 143, Profundidade: ~9] |
#      | 32  cidades    ===>    [Grau: 153, Profundidade: ~8] |
#      | 33  cidades    ===>    [Grau: 161, Profundidade: ~7] |
#      | 34  cidades    ===>    [Grau: 160, Profundidade: ~7] |
#      | 35  cidades    ===>    [Grau: 60, Profundidade: ~19] |
#      | 36  cidades    ===>    [Grau: 69, Profundidade: ~18] |
#      | 37  cidades    ===>    [Grau: 65, Profundidade: ~18] |
#      | 38  cidades    ===>    [Grau: 22, Profundidade: ~23] |
#      | 39  cidades    ===>    [Grau: 27, Profundidade: ~22] |
#      | 40  cidades    ===>    [Grau: 30, Profundidade: ~22] |
#      | 41  cidades    ===>    [Grau: 32, Profundidade: ~22] |
#      | 42  cidades    ===>    [Grau: 59, Profundidade: ~19] |
#      | 43  cidades    ===>    [Grau: 58, Profundidade: ~19] |
#      | 44  cidades    ===>    [Grau: 70, Profundidade: ~17] |
#      | 45  cidades    ===>    [Grau: 71, Profundidade: ~17] |
#      | 46  cidades    ===>    [Grau: 76, Profundidade: ~17] |
#      | 47  cidades    ===>    [Grau: 76, Profundidade: ~17] |
#      | 48  cidades    ===>    [Grau: 79, Profundidade: ~16] |
#      | 49  cidades    ===>    [Grau: 83, Profundidade: ~16] |
#      | 50  cidades    ===>    [Grau: 82, Profundidade: ~16] |
#      | 51  cidades    ===>    [Grau: 9, Profundidade: ~25] |
#      | 52  cidades    ===>    [Grau: 6, Profundidade: ~25] |
#      | 53  cidades    ===>    [Grau: 7, Profundidade: ~25] |
#      | 54  cidades    ===>    [Grau: 27, Profundidade: ~22] |
#      | 55  cidades    ===>    [Grau: 136, Profundidade: ~10] |
#      | 56  cidades    ===>    [Grau: 149, Profundidade: ~8] |
#      | 57  cidades    ===>    [Grau: 154, Profundidade: ~7] |
#      | 58  cidades    ===>    [Grau: 156, Profundidade: ~7] |
#      | 59  cidades    ===>    [Grau: 162, Profundidade: ~7] |
#      | 60  cidades    ===>    [Grau: 161, Profundidade: ~7] |
#      | 61  cidades    ===>    [Grau: 160, Profundidade: ~7] |
#      | 62  cidades    ===>    [Grau: 160, Profundidade: ~7] |
#      | 63  cidades    ===>    [Grau: 115, Profundidade: ~12] |
#      | 64  cidades    ===>    [Grau: 160, Profundidade: ~7] |
#      | 65  cidades    ===>    [Grau: 160, Profundidade: ~7] |
#      | 66  cidades    ===>    [Grau: 160, Profundidade: ~7] |
#      | 67  cidades    ===>    [Grau: 146, Profundidade: ~8] |
#      | 68  cidades    ===>    [Grau: 154, Profundidade: ~7] |
#      | 69  cidades    ===>    [Grau: 157, Profundidade: ~7] |
#      | 70  cidades    ===>    [Grau: 156, Profundidade: ~7] |
#      | 71  cidades    ===>    [Grau: 156, Profundidade: ~7] |
#      | 72  cidades    ===>    [Grau: 155, Profundidade: ~7] |
#      | 73  cidades    ===>    [Grau: 164, Profundidade: ~6] |
#      | 74  cidades    ===>    [Grau: 165, Profundidade: ~6] |
#      | 75  cidades    ===>    [Grau: 153, Profundidade: ~8] |
#      | 76  cidades    ===>    [Grau: 151, Profundidade: ~8] |
#      | 77  cidades    ===>    [Grau: 152, Profundidade: ~8] |
#      | 78  cidades    ===>    [Grau: 153, Profundidade: ~8] |
#      | 79  cidades    ===>    [Grau: 153, Profundidade: ~8] |
#      | 80  cidades    ===>    [Grau: 151, Profundidade: ~8] |
#      | 81  cidades    ===>    [Grau: 49, Profundidade: ~20] |
#      | 82  cidades    ===>    [Grau: 49, Profundidade: ~20] |
#      | 83  cidades    ===>    [Grau: 47, Profundidade: ~20] |
#      | 84  cidades    ===>    [Grau: 49, Profundidade: ~20] |
#      | 85  cidades    ===>    [Grau: 51, Profundidade: ~20] |
#      | 86  cidades    ===>    [Grau: 48, Profundidade: ~20] |
#      | 87  cidades    ===>    [Grau: 49, Profundidade: ~20] |
#      | 88  cidades    ===>    [Grau: 30, Profundidade: ~22] |
#      | 89  cidades    ===>    [Grau: 34, Profundidade: ~22] |
#      | 90  cidades    ===>    [Grau: 49, Profundidade: ~20] |
#      | 91  cidades    ===>    [Grau: 56, Profundidade: ~19] |
#      | 92  cidades    ===>    [Grau: 60, Profundidade: ~19] |
#      | 93  cidades    ===>    [Grau: 30, Profundidade: ~22] |
#      | 94  cidades    ===>    [Grau: 61, Profundidade: ~18] |
#      | 95  cidades    ===>    [Grau: 102, Profundidade: ~14] |
#      | 96  cidades    ===>    [Grau: 109, Profundidade: ~13] |
#      | 97  cidades    ===>    [Grau: 111, Profundidade: ~13] |
#      | 98  cidades    ===>    [Grau: 117, Profundidade: ~12] |
#      | 99  cidades    ===>    [Grau: 115, Profundidade: ~12] |
#      | 100 cidades    ===>    [Grau: 127, Profundidade: ~11] |
#      | 101 cidades    ===>    [Grau: 134, Profundidade: ~10] |
#      | 102 cidades    ===>    [Grau: 132, Profundidade: ~10] |
#      | 103 cidades    ===>    [Grau: 145, Profundidade: ~9] |
#      | 104 cidades    ===>    [Grau: 140, Profundidade: ~9] |
#      | 105 cidades    ===>    [Grau: 139, Profundidade: ~9] |
#      | 106 cidades    ===>    [Grau: 146, Profundidade: ~8] |
#      | 107 cidades    ===>    [Grau: 148, Profundidade: ~8] |
#      | 108 cidades    ===>    [Grau: 147, Profundidade: ~8] |
#      | 109 cidades    ===>    [Grau: 131, Profundidade: ~10] |
#      | 110 cidades    ===>    [Grau: 145, Profundidade: ~9] |
#      | 111 cidades    ===>    [Grau: 147, Profundidade: ~8] |
#      | 112 cidades    ===>    [Grau: 139, Profundidade: ~9] |
#      | 113 cidades    ===>    [Grau: 137, Profundidade: ~9] |
#      | 114 cidades    ===>    [Grau: 156, Profundidade: ~7] |
#      | 115 cidades    ===>    [Grau: 155, Profundidade: ~7] |
#      | 116 cidades    ===>    [Grau: 135, Profundidade: ~10] |
#      | 117 cidades    ===>    [Grau: 134, Profundidade: ~10] |
#      | 118 cidades    ===>    [Grau: 141, Profundidade: ~9] |
#      | 119 cidades    ===>    [Grau: 143, Profundidade: ~9] |
#      | 120 cidades    ===>    [Grau: 159, Profundidade: ~7] |
#      | 121 cidades    ===>    [Grau: 155, Profundidade: ~7] |
#      | 122 cidades    ===>    [Grau: 160, Profundidade: ~7] |
#      | 123 cidades    ===>    [Grau: 167, Profundidade: ~6] |
#      | 124 cidades    ===>    [Grau: 170, Profundidade: ~6] |
#      | 125 cidades    ===>    [Grau: 169, Profundidade: ~6] |
#      | 126 cidades    ===>    [Grau: 170, Profundidade: ~6] |
#      | 127 cidades    ===>    [Grau: 171, Profundidade: ~5] |
#      | 128 cidades    ===>    [Grau: 154, Profundidade: ~7] |
#      | 129 cidades    ===>    [Grau: 158, Profundidade: ~7] |
#      | 130 cidades    ===>    [Grau: 161, Profundidade: ~7] |
#      | 131 cidades    ===>    [Grau: 161, Profundidade: ~7] |
#      | 132 cidades    ===>    [Grau: 155, Profundidade: ~7] |
#      | 133 cidades    ===>    [Grau: 169, Profundidade: ~6] |
#      | 134 cidades    ===>    [Grau: 168, Profundidade: ~6] |
#      | 135 cidades    ===>    [Grau: 163, Profundidade: ~6] |
#      | 136 cidades    ===>    [Grau: 172, Profundidade: ~5] |
#      | 137 cidades    ===>    [Grau: 176, Profundidade: ~5] |
#      | 138 cidades    ===>    [Grau: 177, Profundidade: ~5] |
#      | 139 cidades    ===>    [Grau: 173, Profundidade: ~5] |
#      | 140 cidades    ===>    [Grau: 173, Profundidade: ~5] |
#      | 141 cidades    ===>    [Grau: 175, Profundidade: ~5] |
#      | 142 cidades    ===>    [Grau: 172, Profundidade: ~5] |
#      | 143 cidades    ===>    [Grau: 172, Profundidade: ~5] |
#      | 144 cidades    ===>    [Grau: 172, Profundidade: ~5] |
#      | 145 cidades    ===>    [Grau: 175, Profundidade: ~5] |
#      | 146 cidades    ===>    [Grau: 176, Profundidade: ~5] |
#      | 147 cidades    ===>    [Grau: 179, Profundidade: ~5] |
#      | 148 cidades    ===>    [Grau: 179, Profundidade: ~5] |
#      | 149 cidades    ===>    [Grau: 177, Profundidade: ~5] |
#      | 150 cidades    ===>    [Grau: 175, Profundidade: ~5] |
#      | 151 cidades    ===>    [Grau: 176, Profundidade: ~5] |
#      | 152 cidades    ===>    [Grau: 179, Profundidade: ~5] |
#      | 153 cidades    ===>    [Grau: 175, Profundidade: ~5] |
#      | 154 cidades    ===>    [Grau: 177, Profundidade: ~5] |
#      | 155 cidades    ===>    [Grau: 172, Profundidade: ~5] |
#      | 156 cidades    ===>    [Grau: 172, Profundidade: ~5] |
#      | 157 cidades    ===>    [Grau: 172, Profundidade: ~5] |
#      | 158 cidades    ===>    [Grau: 172, Profundidade: ~5] |
#      | 159 cidades    ===>    [Grau: 177, Profundidade: ~5] |
#      | 160 cidades    ===>    [Grau: 175, Profundidade: ~5] |
#      | 161 cidades    ===>    [Grau: 176, Profundidade: ~5] |
#      | 162 cidades    ===>    [Grau: 176, Profundidade: ~5] |
#      | 163 cidades    ===>    [Grau: 178, Profundidade: ~5] |
#      | 164 cidades    ===>    [Grau: 175, Profundidade: ~5] |
#      | 165 cidades    ===>    [Grau: 171, Profundidade: ~5] |
#      | 166 cidades    ===>    [Grau: 172, Profundidade: ~5] |
#      | 167 cidades    ===>    [Grau: 176, Profundidade: ~5] |
#      | 168 cidades    ===>    [Grau: 175, Profundidade: ~5] |
#      | 169 cidades    ===>    [Grau: 176, Profundidade: ~5] |
#      | 170 cidades    ===>    [Grau: 176, Profundidade: ~5] |
#      | 171 cidades    ===>    [Grau: 174, Profundidade: ~5] |
#      | 172 cidades    ===>    [Grau: 178, Profundidade: ~5] |
#      | 173 cidades    ===>    [Grau: 176, Profundidade: ~5] |
#      | 174 cidades    ===>    [Grau: 178, Profundidade: ~5] |
#      | 175 cidades    ===>    [Grau: 174, Profundidade: ~5] |
#      | 176 cidades    ===>    [Grau: 176, Profundidade: ~5] |
#      | 177 cidades    ===>    [Grau: 176, Profundidade: ~5] |
#      | 178 cidades    ===>    [Grau: 176, Profundidade: ~5] |
#      | 179 cidades    ===>    [Grau: 176, Profundidade: ~5] |
#      | 180 cidades    ===>    [Grau: 176, Profundidade: ~5] |
#      | 181 cidades    ===>    [Grau: 174, Profundidade: ~5] |
#      | 182 cidades    ===>    [Grau: 177, Profundidade: ~5] |
#      | 183 cidades    ===>    [Grau: 177, Profundidade: ~5] |
#      | 184 cidades    ===>    [Grau: 177, Profundidade: ~5] |
#      | 185 cidades    ===>    [Grau: 179, Profundidade: ~5] |
#      | 186 cidades    ===>    [Grau: 176, Profundidade: ~5] |
#      | 187 cidades    ===>    [Grau: 174, Profundidade: ~5] |
#      | 188 cidades    ===>    [Grau: 179, Profundidade: ~5] |
#      | 189 cidades    ===>    [Grau: 182, Profundidade: ~4] |
#      | 190 cidades    ===>    [Grau: 180, Profundidade: ~4] |
#      | 191 cidades    ===>    [Grau: 182, Profundidade: ~4] |
#      | 192 cidades    ===>    [Grau: 176, Profundidade: ~5] |
#      | 193 cidades    ===>    [Grau: 172, Profundidade: ~5] |
#      | 194 cidades    ===>    [Grau: 184, Profundidade: ~4] |
#      | 195 cidades    ===>    [Grau: 180, Profundidade: ~4] |
#      | 196 cidades    ===>    [Grau: 180, Profundidade: ~4] |
#      | 197 cidades    ===>    [Grau: 180, Profundidade: ~4] |
# Iter: 10000, Melhor rota: 197,T: 106.0s, Profundidade para nó g=180 (último melhor): 4, Iters s/ melhora: 106
#      | 198 cidades    ===>    [Grau: 182, Profundidade: ~4] |
#      | 199 cidades    ===>    [Grau: 184, Profundidade: ~4] |
#      | 200 cidades    ===>    [Grau: 184, Profundidade: ~4] |
#      | 201 cidades    ===>    [Grau: 184, Profundidade: ~4] |
#      | 202 cidades    ===>    [Grau: 187, Profundidade: ~4] |
#      | 203 cidades    ===>    [Grau: 181, Profundidade: ~4] |
#      | 204 cidades    ===>    [Grau: 181, Profundidade: ~4] |
#      | 205 cidades    ===>    [Grau: 183, Profundidade: ~4] |
#      | 206 cidades    ===>    [Grau: 181, Profundidade: ~4] |
#      | 207 cidades    ===>    [Grau: 185, Profundidade: ~4] |
#      | 208 cidades    ===>    [Grau: 181, Profundidade: ~4] |
#      | 209 cidades    ===>    [Grau: 186, Profundidade: ~4] |
#      | 210 cidades    ===>    [Grau: 188, Profundidade: ~3] |
#      | 211 cidades    ===>    [Grau: 27, Profundidade: ~22] |
# Iter: 20000, Melhor rota: 211,T: 115.4s, Profundidade para nó g=27 (último melhor): 22, Iters s/ melhora: 7103
# Iter: 30000, Melhor rota: 211,T: 122.6s, Profundidade para nó g=27 (último melhor): 22, Iters s/ melhora: 17103
# Iter: 40000, Melhor rota: 211,T: 131.0s, Profundidade para nó g=27 (último melhor): 22, Iters s/ melhora: 27103
#
# Critério de parada alcançado: nenhuma rota nova foi encontrada por 30000 iterações.
# --------------------------------------------------
# Verificando rota final devido à parada por limite...
# Aviso: A última cidade (Efeitos das chuvas levam município a decretar situação de emergência - rondonopolis.mt.gov.br) não é uma capital.
# Calculando rota de retorno para a capital vizinha mais próxima...
# SUCESSO: Rota estendida para a capital 'Cuiabá'.
# Combustível final: 382.89L
# --------------------------------------------------
#
# ---Busca A* Concluída ---
# Capital Inicial: São Paulo
# Número Total de Cidades ÚNICAS Visitadas (g*): 211
# Distância Total Percorrida na Missão: 43151.16 km
# Total de Paradas para Reabastecimento (capitais intermediárias): 67
# Tempo Total Estimado da Missão: 431.51 horas
# Tamanho final do Cache de Heurística: 29548

# %% [markdown]
# # Interpretação dos resultados:
#
# 1) Com verificação de combustível na heurística:
# depth 5 SP 15 POA, 20 max, 3 min:
# ------Iniciando busca A* a partir de: São Paulo
# ------Tempo limite: 120s.
# ------Referências de profundidade: SP (grau 175, target 5), POA (grau 48, target 15)
# ------Limites de profundidade da heurística: min=3, max=20
#
#
#
#
# ---Busca A* Concluída ---
# Capital Inicial: São Paulo
# Número Total de Cidades ÚNICAS Visitadas (g*): 211
# Distância Total Percorrida na Missão: 45454.10 km
# Total de Paradas para Reabastecimento (capitais intermediárias): 73
# Tempo Total Estimado da Missão: 454.54 horas
# Tamanho final do Cache de Heurística: 28444
#
# 2) sem atualizar comb na heurística (superestima melhor):
# ------Iniciando busca A* a partir de: São Paulo
# ------Tempo limite: 300s.
# ------Referências de profundidade: SP (grau 175, target 5), POA (grau 48, target 20)
# ------Limites de profundidade da heurística: min=2, max=40
# Iniciando busca A*...
# ==> Profundidade para nó inicial (São Paulo, grau 175): 5
#
#
# ---Busca A* Concluída ---
# Capital Inicial: São Paulo
# Número Total de Cidades ÚNICAS Visitadas (g*): 211
# Distância Total Percorrida na Missão: 42967.60 km
# Total de Paradas para Reabastecimento (capitais intermediárias): 66
# Tempo Total Estimado da Missão: 429.68 horas
# Tamanho final do Cache de Heurística: 29548
# depth: 5 SP, 20 POA, 30 max 3 min:
#
#
# 3) Antes de modificar fazia 211 em 68 paradas, então consegui uma leve melhora com a verificação da densidade de cidades não visitas ao redor do nó usada na heurística, superestimar autonomia se provou mais eficiente em inumeros testes, mesmo que parecesse contraintuitivo não atualizar ela dentro da heurítica (ela é devidamente atualizada durante a rota oficial tho).
#
# A versão que será mantida vai ser a de 211 em 66 paradas, assistindo a criação da rota e vendo as quantidades de combustível restantes em 90% dos reabastecimentos, posso concluir que a busca atual está bem otimizada localmente.

# %%
from folium.plugins import MarkerCluster
from IPython.display import display

def plot_route_on_map_final(df_nodes, route_indices, capital_nodes_set_param):
    if not route_indices:
        print("ERRO: rota vazia.")
        return None

    valid_route_indices = [idx for idx in route_indices if idx in df_nodes.index]
    if not valid_route_indices or len(valid_route_indices) < 1:
        print(f"ERRO: len da rota: {len(valid_route_indices)}")
        if not valid_route_indices: return None

    center = [df_nodes.lat.mean(), df_nodes.lon.mean()]
    m = folium.Map(location=center, zoom_start=4)
    route_coords = [(df_nodes.loc[idx, 'lat'], df_nodes.loc[idx, 'lon']) for idx in valid_route_indices]

    if route_coords and len(route_coords) > 1:
        folium.PolyLine(route_coords, color='darkgreen', weight=3.5, opacity=1.0).add_to(m)

    marker_cluster = MarkerCluster().add_to(m)
    for idx in set(valid_route_indices):
        lat, lon = df_nodes.loc[idx, ['lat', 'lon']]
        is_capital = df_nodes.loc[idx, 'is_cap']
        cidade_info = str(df_nodes.loc[idx, 'cidade'])

        color = 'blue'
        icon_type = 'info-sign'
        if is_capital:
            cidade_info += ' (Capital)'
            color = 'red'
            icon_type = 'plane'
        if idx == valid_route_indices[0]:
            color = 'green'

        folium.Marker(
            [lat, lon], popup=folium.Popup(cidade_info, max_width=300),
            icon=folium.Icon(color=color, icon=icon_type)
        ).add_to(marker_cluster)

    if valid_route_indices:
        start_lat, start_lon = df_nodes.loc[valid_route_indices[0], ['lat', 'lon']]
        folium.CircleMarker(
            [start_lat, start_lon], radius=10, color='green', fill=True, fill_opacity=0.6,
            popup=f"Ponto de Partida: {df_nodes.loc[valid_route_indices[0], 'cidade']}"
        ).add_to(m)
    return m

if 'rota_global_final' in locals() and rota_global_final:
    print("\nPlotando a melhor rota...")
    if 'id_set_cap' not in locals():
        id_set_cap = set(nome_cap_para_id.values()) if 'nome_cap_para_id' in locals() else set()

    mapa_resultado_a_star = plot_route_on_map_final(df, rota_global_final, id_set_cap)
    if mapa_resultado_a_star:
        display(mapa_resultado_a_star)
else:
    print("\n ERRO: não gerou a rota")
# Out:
# Plotando a melhor rota...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08501e610af86d1610f20908fe2d708b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08501e610af86d1610f20908fe2d708b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08501e610af86d1610f20908fe2d708b = L.map(
#                 &quot;map_08501e610af86d1610f20908fe2d708b&quot;,
#                 {
#                     center: [-17.6457966163522, -45.819479729559745],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbb8922c224e5b7fc5f5a34600a227bc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dbb8922c224e5b7fc5f5a34600a227bc.addTo(map_08501e610af86d1610f20908fe2d708b);
#
#
#             var poly_line_a2b7996e4a7dc0a9f536dd223ad6205b = L.polyline(
#                 [[-23.567387, -46.570383], [-20.338374, -40.293957], [-20.320154, -40.322209], [-17.53775, -39.744518], [-18.718447, -39.858201], [-19.398106, -40.065306], [-19.53627, -40.630318], [-20.15677, -40.275217], [-20.294678, -40.390559], [-20.320154, -40.322209], [-17.86254, -41.509635], [-20.665975, -40.495021], [-20.320154, -40.322209], [-21.751899, -41.330476], [-20.850112, -41.111919], [-22.837203, -42.103529], [-22.880765, -42.020075], [-22.877438, -42.341096], [-22.829547, -43.032335], [-22.876652, -43.227875], [-22.785253, -43.309888], [-22.759835, -43.450345], [-22.764556, -43.399625], [-22.807514, -43.41661], [-22.871251, -43.775041], [-22.368705, -41.775064], [-21.210591, -41.886203], [-22.286461, -42.532771], [-22.523941, -41.936967], [-22.409005, -42.962957], [-22.510599, -43.177337], [-22.871251, -43.775041], [-21.132047, -42.361075], [-18.852882, -41.947081], [-19.481032, -42.520351], [-19.892495, -43.825557], [-19.937524, -43.926453], [-15.737939, -48.283444], [-16.056078, -48.037211], [-15.794087, -47.887905], [-10.163253, -48.351044], [-12.078372, -45.800464], [-10.163253, -48.351044], [-12.478815, -49.126811], [-10.163253, -48.351044], [-7.191329, -48.208705], [-10.163253, -48.351044], [-15.540945, -47.335816], [-15.45311, -47.614847], [-15.794087, -47.887905], [-16.069575, -47.984111], [-16.328826, -48.957218], [-16.258541, -47.95572], [-16.67331, -49.255814], [-16.718575, -49.087967], [-16.822147, -49.243326], [-15.794087, -47.887905], [-17.794543, -50.929681], [-16.67331, -49.255814], [-15.569989, -56.073252], [-14.623785, -57.491299], [-15.569989, -56.073252], [-12.551777, -55.725914], [-15.569989, -56.073252], [-16.67331, -49.255814], [-17.886232, -51.720818], [-16.67331, -49.255814], [-18.417682, -49.22087], [-18.973068, -49.462235], [-18.169573, -47.947703], [-18.64827, -48.191605], [-16.67331, -49.255814], [-19.458287, -44.239595], [-19.965379, -44.197551], [-19.983893, -43.849783], [-20.028038, -44.056665], [-19.937524, -43.926453], [-16.722707, -43.865422], [-19.69303, -43.919915], [-19.766022, -44.085824], [-19.943446, -44.066345], [-19.937524, -43.926453], [-21.118597, -42.936786], [-22.745863, -42.860343], [-21.760924, -43.348817], [-22.654349, -43.040246], [-22.896452, -43.075823], [-22.916955, -42.819824], [-22.802331, -43.371885], [-22.71743, -43.55567], [-22.871251, -43.775041], [-25.537702, -49.200082], [-25.591645, -49.40194], [-25.6414, -49.323293], [-25.442198, -49.199197], [-25.432956, -49.271848], [-25.459491, -49.528841], [-25.432956, -49.271848], [-29.945519, -50.990793], [-29.824868, -51.151875], [-30.081897, -51.02482], [-29.918697, -51.18103], [-29.686326, -51.128605], [-30.030037, -51.22866], [-29.765867, -51.146235], [-30.030037, -51.22866], [-32.050446, -52.08677], [-31.719598, -52.34432], [-29.719768, -52.429929], [-29.167402, -51.51556], [-29.166899, -51.17886], [-30.030037, -51.22866], [-31.330502, -54.107083], [-30.030037, -51.22866], [-28.261767, -52.407095], [-27.633406, -52.275877], [-27.106837, -52.617031], [-30.030037, -51.22866], [-28.673572, -49.36594], [-27.817259, -50.330222], [-30.030037, -51.22866], [-28.480034, -49.005268], [-27.647044, -48.670288], [-27.587796, -48.547637], [-27.590312, -48.616023], [-27.026456, -48.649996], [-26.916108, -49.057631], [-27.09831, -48.915163], [-26.991819, -48.634617], [-26.304

# %%
print("\n--- Alternative Route Animation with ipyleaflet ---")

try:
    from ipyleaflet import Map, Marker, Polyline, DivIcon
    from IPython.display import display
    import asyncio
except ImportError:
    print("ipyleaflet não encontrado. Tentando instalar...")
    # !pip install ipyleaflet
    from ipyleaflet import Map, Marker, Polyline, DivIcon
    from IPython.display import display
    import asyncio
    print("Bibliotecas instaladas. Pode ser necessário reiniciar o kernel e/ou confiar no notebook.")

if ('rota_global_final' in locals() and rota_global_final and
    'df' in locals() and
    'fuel_levels_raw_from_astar' in locals() and fuel_levels_raw_from_astar and
    len(rota_global_final) == len(fuel_levels_raw_from_astar)):

    temp_fuel_map = {node_idx: fuel_levels_raw_from_astar[i] for i, node_idx in enumerate(rota_global_final)}
    nodes_for_animation_filtered = [idx for idx in rota_global_final if idx in df.index]

    fuel_levels_for_animation = []
    nodes_for_animation = []

    if nodes_for_animation_filtered:
        for idx in nodes_for_animation_filtered:
            if idx in temp_fuel_map:
                nodes_for_animation.append(idx)
                fuel_levels_for_animation.append(temp_fuel_map[idx])
            else:
                print(f"Aviso: Nó {idx} de nodes_for_animation_filtered não encontrado no mapeamento de combustível. Será ignorado.")

    if not nodes_for_animation:
        print("Error: 'nodes_for_animation' está vazia após filtragem ou houve erro no alinhamento de combustível.")
    elif len(nodes_for_animation) != len(fuel_levels_for_animation):
        print(f"Error: Discrepância de tamanho entre 'nodes_for_animation' ({len(nodes_for_animation)}) e 'fuel_levels_for_animation' ({len(fuel_levels_for_animation)}) após alinhamento.")
    else:
        coordenadas_animation = [(df.loc[node_idx, 'lat'], df.loc[node_idx, 'lon']) for node_idx in nodes_for_animation]

        if not coordenadas_animation:
            print("Error: Could not extract coordinates for the animation.")
        else:
            map_center_animation = coordenadas_animation[0]
            ipyleaflet_map = Map(center=map_center_animation, zoom=4, scroll_wheel_zoom=True)
            ipyleaflet_map.layout.height = '800px'
            ipyleaflet_map.layout.width = '100%'

            animated_line = Polyline(locations=[], color="purple", fill=False, weight=3)
            ipyleaflet_map.add_layer(animated_line)

            text_label_tracker = {'active_label_marker': None}

            async def animar_rota_on_map():
                for i, coord in enumerate(coordenadas_animation):
                    node_idx = nodes_for_animation[i]
                    cidade_nome = str(df.loc[node_idx, 'cidade'])
                    is_capital = df.loc[node_idx, 'is_cap']

                    fuel_value_at_node = fuel_levels_for_animation[i]
                    fuel_text = f"{fuel_value_at_node:.2f}L"

                    node_pin_marker = Marker(location=coord, draggable=False)
                    ipyleaflet_map.add_layer(node_pin_marker)

                    animated_line.locations = animated_line.locations + [coord]
                    ipyleaflet_map.center = coord

                    if text_label_tracker['active_label_marker']:
                        try:
                            ipyleaflet_map.remove_layer(text_label_tracker['active_label_marker'])
                        except Exception as e_remove:
                            pass
                        text_label_tracker['active_label_marker'] = None

                    info_html_lines = [f"<div style='font-weight: bold;'>{cidade_nome}</div>", f"Combustível: {fuel_text}"]
                    if i == 0:
                        info_html_lines.append("(COMEÇO)")
                    elif is_capital:
                        info_html_lines.append("(REABASTECIMENTO)")
                    label_html_content = "<br>".join(info_html_lines)

                    styled_div_html = f"""
                    <div style="color: black;
                                background-color: rgba(255, 255, 255, 0.9);
                                border: 1px solid grey;
                                border-radius: 5px;
                                padding: 6px 8px;
                                font-size: 10pt;
                                font-family: Arial, sans-serif;
                                box-shadow: 3px 3px 5px rgba(0,0,0,0.4);
                                width: 230px;
                                z-index: 10000 !important;
                                ">
                        {label_html_content}
                    </div>
                    """
                    text_label_icon = DivIcon(html=styled_div_html, icon_size=None, icon_anchor=[0,0])

                    current_text_label_marker = Marker(location=coord, icon=text_label_icon, draggable=False)

                    ipyleaflet_map.add_layer(current_text_label_marker)
                    text_label_tracker['active_label_marker'] = current_text_label_marker

                    await asyncio.sleep(0.0001)

                if text_label_tracker['active_label_marker']:
                    await asyncio.sleep(2.0)
                    try:
                        ipyleaflet_map.remove_layer(text_label_tracker['active_label_marker'])
                    except Exception:
                        pass
                    text_label_tracker['active_label_marker'] = None

            display(ipyleaflet_map)
            print("ANIMAÇÃO DA ROTA COMEÇANDO...")

            try:
                await animar_rota_on_map()
            except Exception as e:
                print(f"ERRO: animacao {e}")
else:
    error_messages = []
    if 'rota_global_final' not in locals() or not rota_global_final:
        error_messages.append("'rota_global_final' não definida ou vazia")
    if 'df' not in locals():
        error_messages.append("'df' DataFrame não definido")
    if 'fuel_levels_raw_from_astar' not in locals() or not fuel_levels_raw_from_astar:
        error_messages.append("'fuel_levels_raw_from_astar' (lista de combustíveis) não gerada ou vazia")
    elif 'rota_global_final' in locals() and 'fuel_levels_raw_from_astar' in locals() and len(rota_global_final) != len(fuel_levels_raw_from_astar):
        error_messages.append("Inconsistência: Comprimento da rota e dos níveis de combustível não correspondem.")
    print(f"Error: Cannot proceed with ipyleaflet animation because: {', '.join(error_messages)}.")
# Out:
# --- Alternative Route Animation with ipyleaflet ---
# Map(center=[np.float64(-23.567387), np.float64(-46.570383)], controls=(ZoomControl(options=['position', 'zoom_…
# ANIMAÇÃO DA ROTA COMEÇANDO...

# %%
print("\n--- Rota Detalhada por Trechos de Reabastecimento ---")

if ('rota_global_final' in locals() and rota_global_final and
    'df' in locals() and
    'fuel_levels_raw_from_astar' in locals() and fuel_levels_raw_from_astar and
    len(rota_global_final) == len(fuel_levels_raw_from_astar)):

    trecho_counter = 1

    for i, node_idx in enumerate(rota_global_final):
        is_capital = df.loc[node_idx, 'is_cap']

        if is_capital:
            display_name = df.loc[node_idx, 'cidade']
        else:
            display_name = f"Cidade (Índice: {node_idx})"

        # Trata o início do primeiro trecho
        if i == 0:
            print(f"\n## TRECHO {trecho_counter}")
            print(f"- {display_name:<35} | Autonimia: {AUTONOMIA:.2f}Km (Origem da Rota)")
            continue

        auto_na_chegada = fuel_levels_raw_from_astar[i]

        print(f"- {display_name:<35} | Autonimia na Chegada: {auto_na_chegada:.2f}Km")

        if is_capital:
            if i == len(rota_global_final) - 1:
                print("  (Destino Final da Rota)")
            else:
                print("  (Fim do Trecho - Reabastecimento)")
                trecho_counter += 1
                print(f"\n## TRECHO {trecho_counter}")
                print(f"- {display_name:<35} | Autonimia: {AUTONOMIA:.2f}Km (Partida do Trecho)")

else:
    print("ERRO: rota não válida")
# Out:
# --- Rota Detalhada por Trechos de Reabastecimento ---
#
# ## TRECHO 1
# - São Paulo                           | Autonimia: 750.00Km (Origem da Rota)
# - Cidade (Índice: 282)                | Autonimia na Chegada: 9.94Km
# - Vitória                             | Autonimia na Chegada: 6.36Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 2
# - Vitória                             | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 220)                | Autonimia na Chegada: 434.70Km
# - Cidade (Índice: 207)                | Autonimia na Chegada: 302.87Km
# - Cidade (Índice: 292)                | Autonimia na Chegada: 224.22Km
# - Cidade (Índice: 103)                | Autonimia na Chegada: 163.02Km
# - Cidade (Índice: 293)                | Autonimia na Chegada: 84.67Km
# - Cidade (Índice: 39)                 | Autonimia na Chegada: 65.17Km
# - Vitória                             | Autonimia na Chegada: 57.50Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 3
# - Vitória                             | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 155)                | Autonimia na Chegada: 449.59Km
# - Cidade (Índice: 228)                | Autonimia na Chegada: 120.18Km
# - Vitória                             | Autonimia na Chegada: 77.72Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 4
# - Vitória                             | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 41)                 | Autonimia na Chegada: 559.49Km
# - Cidade (Índice: 106)                | Autonimia na Chegada: 456.69Km
# - Cidade (Índice: 170)                | Autonimia na Chegada: 213.19Km
# - Cidade (Índice: 317)                | Autonimia na Chegada: 203.36Km
# - Cidade (Índice: 209)                | Autonimia na Chegada: 170.47Km
# - Cidade (Índice: 23)                 | Autonimia na Chegada: 99.44Km
# - Cidade (Índice: 56)                 | Autonimia na Chegada: 78.73Km
# - Cidade (Índice: 82)                 | Autonimia na Chegada: 65.54Km
# - Cidade (Índice: 9)                  | Autonimia na Chegada: 50.87Km
# - Cidade (Índice: 28)                 | Autonimia na Chegada: 45.64Km
# - Cidade (Índice: 114)                | Autonimia na Chegada: 40.56Km
# - Rio de Janeiro                      | Autonimia na Chegada: 3.15Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 5
# - Rio de Janeiro                      | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 173)                | Autonimia na Chegada: 537.25Km
# - Cidade (Índice: 110)                | Autonimia na Chegada: 407.97Km
# - Cidade (Índice: 231)                | Autonimia na Chegada: 270.96Km
# - Cidade (Índice: 236)                | Autonimia na Chegada: 204.26Km
# - Cidade (Índice: 17)                 | Autonimia na Chegada: 98.06Km
# - Cidade (Índice: 143)                | Autonimia na Chegada: 73.31Km
# - Rio de Janeiro                      | Autonimia na Chegada: 0.04Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 6
# - Rio de Janeiro                      | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 244)                | Autonimia na Chegada: 507.83Km
# - Cidade (Índice: 301)                | Autonimia na Chegada: 250.73Km
# - Cidade (Índice: 16)                 | Autonimia na Chegada: 158.51Km
# - Cidade (Índice: 6)                  | Autonimia na Chegada: 14.41Km
# - Belo Horizonte                      | Autonimia na Chegada: 2.73Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 7
# - Belo Horizonte                      | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 174)                | Autonimia na Chegada: 93.78Km
# - Cidade (Índice: 69)                 | Autonimia na Chegada: 49.68Km
# - Brasília                            | Autonimia na Chegada: 16.46Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 8
# - Brasília                            | Autonimia: 750.00Km (Partida do Trecho)
# - Palmas                              | Autonimia na Chegada: 121.87Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 9
# - Palmas                              | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 192)                | Autonimia na Chegada: 399.60Km
# - Palmas                              | Autonimia na Chegada: 49.19Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 10
# - Palmas                              | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 227)                | Autonimia na Chegada: 478.99Km
# - Palmas                              | Autonimia na Chegada: 207.97Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 11
# - Palmas                              | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 277)                | Autonimia na Chegada: 419.17Km
# - Palmas                              | Autonimia na Chegada: 88.33Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 12
# - Palmas                              | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 233)                | Autonimia na Chegada: 141.99Km
# - Cidade (Índice: 249)                | Autonimia na Chegada: 110.54Km
# - Brasília                            | Autonimia na Chegada: 62.66Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 13
# - Brasília                            | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 14)                 | Autonimia na Chegada: 717.69Km
# - Cidade (Índice: 60)                 | Autonimia na Chegada: 609.85Km
# - Cidade (Índice: 64)                 | Autonimia na Chegada: 502.68Km
# - Goiânia                             | Autonimia na Chegada: 356.57Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 14
# - Goiânia                             | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 90)                 | Autonimia na Chegada: 338.00Km
# - Cidade (Índice: 261)                | Autonimia na Chegada: 317.85Km
# - Brasília                            | Autonimia na Chegada: 133.48Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 15
# - Brasília                            | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 161)                | Autonimia na Chegada: 357.17Km
# - Goiânia                             | Autonimia na Chegada: 140.05Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 16
# - Goiânia                             | Autonimia: 750.00Km (Partida do Trecho)
# - Cuiabá                              | Autonimia na Chegada: 11.53Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 17
# - Cuiabá                              | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 157)                | Autonimia na Chegada: 564.94Km
# - Cuiabá                              | Autonimia na Chegada: 379.89Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 18
# - Cuiabá                              | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 160)                | Autonimia na Chegada: 412.31Km
# - Cuiabá                              | Autonimia na Chegada: 74.61Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 19
# - Cuiabá                              | Autonimia: 750.00Km (Partida do Trecho)
# - Goiânia                             | Autonimia na Chegada: 11.53Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 20
# - Goiânia                             | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 22)                 | Autonimia na Chegada: 455.58Km
# - Goiânia                             | Autonimia na Chegada: 161.15Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 21
# - Goiânia                             | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 84)                 | Autonimia na Chegada: 556.00Km
# - Cidade (Índice: 290)                | Autonimia na Chegada: 489.22Km
# - Cidade (Índice: 101)                | Autonimia na Chegada: 306.28Km
# - Cidade (Índice: 172)                | Autonimia na Chegada: 247.15Km
# - Goiânia                             | Autonimia na Chegada: 0.30Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 22
# - Goiânia                             | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 7)                  | Autonimia na Chegada: 135.99Km
# - Cidade (Índice: 13)                 | Autonimia na Chegada: 79.43Km
# - Cidade (Índice: 171)                | Autonimia na Chegada: 43.03Km
# - Cidade (Índice: 210)                | Autonimia na Chegada: 20.87Km
# - Belo Horizonte                      | Autonimia na Chegada: 3.94Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 23
# - Belo Horizonte                      | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 20)                 | Autonimia na Chegada: 392.47Km
# - Cidade (Índice: 96)                 | Autonimia na Chegada: 62.14Km
# - Cidade (Índice: 193)                | Autonimia na Chegada: 42.97Km
# - Cidade (Índice: 289)                | Autonimia na Chegada: 23.13Km
# - Belo Horizonte                      | Autonimia na Chegada: 8.50Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 24
# - Belo Horizonte                      | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 99)                 | Autonimia na Chegada: 583.06Km
# - Cidade (Índice: 25)                 | Autonimia na Chegada: 401.95Km
# - Cidade (Índice: 95)                 | Autonimia na Chegada: 281.44Km
# - Cidade (Índice: 131)                | Autonimia na Chegada: 177.14Km
# - Cidade (Índice: 206)                | Autonimia na Chegada: 149.98Km
# - Cidade (Índice: 211)                | Autonimia na Chegada: 123.66Km
# - Cidade (Índice: 148)                | Autonimia na Chegada: 65.67Km
# - Cidade (Índice: 247)                | Autonimia na Chegada: 44.60Km
# - Rio de Janeiro                      | Autonimia na Chegada: 16.34Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 25
# - Rio de Janeiro                      | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 27)                 | Autonimia na Chegada: 125.09Km
# - Cidade (Índice: 74)                 | Autonimia na Chegada: 103.97Km
# - Cidade (Índice: 85)                 | Autonimia na Chegada: 94.34Km
# - Cidade (Índice: 122)                | Autonimia na Chegada: 68.93Km
# - Curitiba                            | Autonimia na Chegada: 61.56Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 26
# - Curitiba                            | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 183)                | Autonimia na Chegada: 35.59Km
# - Curitiba                            | Autonimia na Chegada: 9.62Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 27
# - Curitiba                            | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 31)                 | Autonimia na Chegada: 220.48Km
# - Cidade (Índice: 40)                 | Autonimia na Chegada: 199.95Km
# - Cidade (Índice: 45)                 | Autonimia na Chegada: 168.86Km
# - Cidade (Índice: 83)                 | Autonimia na Chegada: 145.29Km
# - Cidade (Índice: 218)                | Autonimia na Chegada: 118.96Km
# - Porto Alegre                        | Autonimia na Chegada: 79.55Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 28
# - Porto Alegre                        | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 238)                | Autonimia na Chegada: 49.12Km
# - Porto Alegre                        | Autonimia na Chegada: 18.69Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 29
# - Porto Alegre                        | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 203)                | Autonimia na Chegada: 510.93Km
# - Cidade (Índice: 269)                | Autonimia na Chegada: 466.83Km
# - Cidade (Índice: 115)                | Autonimia na Chegada: 244.31Km
# - Cidade (Índice: 182)                | Autonimia na Chegada: 136.55Km
# - Cidade (Índice: 279)                | Autonimia na Chegada: 103.86Km
# - Porto Alegre                        | Autonimia na Chegada: 7.76Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 30
# - Porto Alegre                        | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 158)                | Autonimia na Chegada: 439.08Km
# - Porto Alegre                        | Autonimia na Chegada: 128.16Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 31
# - Porto Alegre                        | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 123)                | Autonimia na Chegada: 522.50Km
# - Cidade (Índice: 105)                | Autonimia na Chegada: 451.45Km
# - Cidade (Índice: 86)                 | Autonimia na Chegada: 383.90Km
# - Porto Alegre                        | Autonimia na Chegada: 31.72Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 32
# - Porto Alegre                        | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 243)                | Autonimia na Chegada: 514.76Km
# - Cidade (Índice: 54)                 | Autonimia na Chegada: 380.64Km
# - Porto Alegre                        | Autonimia na Chegada: 119.52Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 33
# - Porto Alegre                        | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 113)                | Autonimia na Chegada: 473.91Km
# - Cidade (Índice: 102)                | Autonimia na Chegada: 375.63Km
# - Cidade (Índice: 298)                | Autonimia na Chegada: 361.87Km
# - Cidade (Índice: 312)                | Autonimia na Chegada: 355.12Km
# - Cidade (Índice: 58)                 | Autonimia na Chegada: 292.33Km
# - Cidade (Índice: 199)                | Autonimia na Chegada: 250.12Km
# - Cidade (Índice: 251)                | Autonimia na Chegada: 225.42Km
# - Cidade (Índice: 2)                  | Autonimia na Chegada: 195.22Km
# - Florianópolis                       | Autonimia na Chegada: 115.87Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 34
# - Florianópolis                       | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 184)                | Autonimia na Chegada: 85.24Km
# - Florianópolis                       | Autonimia na Chegada: 54.61Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 35
# - Florianópolis                       | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 93)                 | Autonimia na Chegada: 469.50Km
# - Cidade (Índice: 24)                 | Autonimia na Chegada: 334.34Km
# - Cidade (Índice: 222)                | Autonimia na Chegada: 82.69Km
# - Florianópolis                       | Autonimia na Chegada: 12.97Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 36
# - Florianópolis                       | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 35)                 | Autonimia na Chegada: 335.83Km
# - Cidade (Índice: 57)                 | Autonimia na Chegada: 320.32Km
# - Cidade (Índice: 195)                | Autonimia na Chegada: 22.60Km
# - Cidade (Índice: 245)                | Autonimia na Chegada: 14.97Km
# - Curitiba                            | Autonimia na Chegada: 1.37Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 37
# - Curitiba                            | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 11)                 | Autonimia na Chegada: 406.03Km
# - Cidade (Índice: 65)                 | Autonimia na Chegada: 398.89Km
# - Cidade (Índice: 49)                 | Autonimia na Chegada: 329.51Km
# - Cidade (Índice: 271)                | Autonimia na Chegada: 317.28Km
# - Curitiba                            | Autonimia na Chegada: 13.50Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 38
# - Curitiba                            | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 63)                 | Autonimia na Chegada: 420.75Km
# - Cidade (Índice: 212)                | Autonimia na Chegada: 82.14Km
# - Curitiba                            | Autonimia na Chegada: 61.34Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 39
# - Curitiba                            | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 273)                | Autonimia na Chegada: 674.55Km
# - Cidade (Índice: 66)                 | Autonimia na Chegada: 362.02Km
# - Curitiba                            | Autonimia na Chegada: 82.33Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 40
# - Curitiba                            | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 201)                | Autonimia na Chegada: 385.55Km
# - Curitiba                            | Autonimia na Chegada: 21.11Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 41
# - Curitiba                            | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 305)                | Autonimia na Chegada: 131.67Km
# - Cidade (Índice: 310)                | Autonimia na Chegada: 106.56Km
# - Cidade (Índice: 107)                | Autonimia na Chegada: 70.62Km
# - Rio de Janeiro                      | Autonimia na Chegada: 12.78Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 42
# - Rio de Janeiro                      | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 55)                 | Autonimia na Chegada: 359.27Km
# - Cidade (Índice: 119)                | Autonimia na Chegada: 295.21Km
# - Cidade (Índice: 132)                | Autonimia na Chegada: 167.13Km
# - Belo Horizonte                      | Autonimia na Chegada: 85.42Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 43
# - Belo Horizonte                      | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 306)                | Autonimia na Chegada: 606.00Km
# - Cidade (Índice: 313)                | Autonimia na Chegada: 352.23Km
# - Vitória                             | Autonimia na Chegada: 84.02Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 44
# - Vitória                             | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 21)                 | Autonimia na Chegada: 260.55Km
# - Belo Horizonte                      | Autonimia na Chegada: 149.61Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 45
# - Belo Horizonte                      | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 37)                 | Autonimia na Chegada: 439.77Km
# - Brasília                            | Autonimia na Chegada: 96.16Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 46
# - Brasília                            | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 265)                | Autonimia na Chegada: 400.07Km
# - Brasília                            | Autonimia na Chegada: 50.14Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 47
# - Brasília                            | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 185)                | Autonimia na Chegada: 172.10Km
# - Belo Horizonte                      | Autonimia na Chegada: 68.51Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 48
# - Belo Horizonte                      | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 0)                  | Autonimia na Chegada: 274.05Km
# - Cidade (Índice: 8)                  | Autonimia na Chegada: 255.41Km
# - Cidade (Índice: 15)                 | Autonimia na Chegada: 155.35Km
# - Cidade (Índice: 50)                 | Autonimia na Chegada: 102.23Km
# - Cidade (Índice: 88)                 | Autonimia na Chegada: 65.50Km
# - Cidade (Índice: 100)                | Autonimia na Chegada: 41.58Km
# - Cidade (Índice: 177)                | Autonimia na Chegada: 36.22Km
# - Cidade (Índice: 239)                | Autonimia na Chegada: 31.74Km
# - São Paulo                           | Autonimia na Chegada: 0.05Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 49
# - São Paulo                           | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 44)                 | Autonimia na Chegada: 702.55Km
# - Cidade (Índice: 53)                 | Autonimia na Chegada: 691.75Km
# - Cidade (Índice: 61)                 | Autonimia na Chegada: 525.09Km
# - Cidade (Índice: 71)                 | Autonimia na Chegada: 441.48Km
# - Cidade (Índice: 79)                 | Autonimia na Chegada: 369.92Km
# - Cidade (Índice: 108)                | Autonimia na Chegada: 313.75Km
# - Cidade (Índice: 111)                | Autonimia na Chegada: 271.58Km
# - Cidade (Índice: 112)                | Autonimia na Chegada: 210.57Km
# - Cidade (Índice: 117)                | Autonimia na Chegada: 138.42Km
# - Cidade (Índice: 120)                | Autonimia na Chegada: 123.17Km
# - Cidade (Índice: 128)                | Autonimia na Chegada: 66.18Km
# - Cidade (Índice: 166)                | Autonimia na Chegada: 57.06Km
# - Cidade (Índice: 213)                | Autonimia na Chegada: 46.16Km
# - Cidade (Índice: 287)                | Autonimia na Chegada: 28.89Km
# - São Paulo                           | Autonimia na Chegada: 6.08Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 50
# - São Paulo                           | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 80)                 | Autonimia na Chegada: 383.86Km
# - Cidade (Índice: 133)                | Autonimia na Chegada: 96.20Km
# - Cidade (Índice: 179)                | Autonimia na Chegada: 48.92Km
# - Cidade (Índice: 168)                | Autonimia na Chegada: 36.86Km
# - São Paulo                           | Autonimia na Chegada: 0.46Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 51
# - São Paulo                           | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 118)                | Autonimia na Chegada: 616.22Km
# - Cidade (Índice: 125)                | Autonimia na Chegada: 538.72Km
# - Cidade (Índice: 165)                | Autonimia na Chegada: 364.42Km
# - Cidade (Índice: 188)                | Autonimia na Chegada: 335.37Km
# - Cidade (Índice: 190)                | Autonimia na Chegada: 91.30Km
# - Cidade (Índice: 215)                | Autonimia na Chegada: 71.68Km
# - Cidade (Índice: 242)                | Autonimia na Chegada: 58.40Km
# - Cidade (Índice: 288)                | Autonimia na Chegada: 22.95Km
# - Cidade (Índice: 276)                | Autonimia na Chegada: 15.15Km
# - São Paulo                           | Autonimia na Chegada: 0.56Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 52
# - São Paulo                           | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 191)                | Autonimia na Chegada: 670.69Km
# - Cidade (Índice: 196)                | Autonimia na Chegada: 622.72Km
# - Cidade (Índice: 198)                | Autonimia na Chegada: 348.92Km
# - Cidade (Índice: 232)                | Autonimia na Chegada: 133.80Km
# - Cidade (Índice: 270)                | Autonimia na Chegada: 69.78Km
# - Cidade (Índice: 268)                | Autonimia na Chegada: 29.51Km
# - São Paulo                           | Autonimia na Chegada: 13.42Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 53
# - São Paulo                           | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 241)                | Autonimia na Chegada: 723.02Km
# - Cidade (Índice: 253)                | Autonimia na Chegada: 583.67Km
# - Cidade (Índice: 254)                | Autonimia na Chegada: 487.38Km
# - Cidade (Índice: 263)                | Autonimia na Chegada: 358.57Km
# - Cidade (Índice: 275)                | Autonimia na Chegada: 178.45Km
# - Cidade (Índice: 280)                | Autonimia na Chegada: 140.65Km
# - São Paulo                           | Autonimia na Chegada: 58.66Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 54
# - São Paulo                           | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 294)                | Autonimia na Chegada: 599.59Km
# - Cidade (Índice: 307)                | Autonimia na Chegada: 473.60Km
# - Cidade (Índice: 308)                | Autonimia na Chegada: 437.65Km
# - Cidade (Índice: 314)                | Autonimia na Chegada: 369.70Km
# - Cidade (Índice: 315)                | Autonimia na Chegada: 294.43Km
# - Cidade (Índice: 30)                 | Autonimia na Chegada: 256.63Km
# - Cidade (Índice: 62)                 | Autonimia na Chegada: 180.67Km
# - Cidade (Índice: 89)                 | Autonimia na Chegada: 125.42Km
# - São Paulo                           | Autonimia na Chegada: 31.73Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 55
# - São Paulo                           | Autonimia: 750.00Km (Partida do Trecho)
# - Belo Horizonte                      | Autonimia na Chegada: 262.73Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 56
# - Belo Horizonte                      | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 29)                 | Autonimia na Chegada: 432.31Km
# - Goiânia                             | Autonimia na Chegada: 25.93Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 57
# - Goiânia                             | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 116)                | Autonimia na Chegada: 386.22Km
# - Goiânia                             | Autonimia na Chegada: 22.44Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 58
# - Goiânia                             | Autonimia: 750.00Km (Partida do Trecho)
# - Belo Horizonte                      | Autonimia na Chegada: 80.57Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 59
# - Belo Horizonte                      | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 52)                 | Autonimia na Chegada: 381.31Km
# - Cidade (Índice: 150)                | Autonimia na Chegada: 134.53Km
# - Cidade (Índice: 159)                | Autonimia na Chegada: 107.91Km
# - São Paulo                           | Autonimia na Chegada: 0.09Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 60
# - São Paulo                           | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 5)                  | Autonimia na Chegada: 544.46Km
# - Cidade (Índice: 38)                 | Autonimia na Chegada: 477.48Km
# - Cidade (Índice: 92)                 | Autonimia na Chegada: 408.76Km
# - Cidade (Índice: 135)                | Autonimia na Chegada: 370.10Km
# - Cidade (Índice: 137)                | Autonimia na Chegada: 167.61Km
# - São Paulo                           | Autonimia na Chegada: 5.40Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 61
# - São Paulo                           | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 141)                | Autonimia na Chegada: 497.74Km
# - Cidade (Índice: 162)                | Autonimia na Chegada: 262.04Km
# - Cidade (Índice: 225)                | Autonimia na Chegada: 229.53Km
# - Cidade (Índice: 234)                | Autonimia na Chegada: 180.74Km
# - São Paulo                           | Autonimia na Chegada: 22.37Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 62
# - São Paulo                           | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 156)                | Autonimia na Chegada: 456.21Km
# - Cidade (Índice: 262)                | Autonimia na Chegada: 321.84Km
# - Belo Horizonte                      | Autonimia na Chegada: 28.71Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 63
# - Belo Horizonte                      | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 214)                | Autonimia na Chegada: 566.83Km
# - Cidade (Índice: 284)                | Autonimia na Chegada: 330.42Km
# - Cidade (Índice: 77)                 | Autonimia na Chegada: 255.23Km
# - São Paulo                           | Autonimia na Chegada: 57.30Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 64
# - São Paulo                           | Autonimia: 750.00Km (Partida do Trecho)
# - Belo Horizonte                      | Autonimia na Chegada: 262.73Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 65
# - Belo Horizonte                      | Autonimia: 750.00Km (Partida do Trecho)
# - Goiânia                             | Autonimia na Chegada: 80.57Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 66
# - Goiânia                             | Autonimia: 750.00Km (Partida do Trecho)
# - Cuiabá                              | Autonimia na Chegada: 11.53Km
#   (Fim do Trecho - Reabastecimento)
#
# ## TRECHO 67
# - Cuiabá                              | Autonimia: 750.00Km (Partida do Trecho)
# - Cidade (Índice: 272)                | Autonimia na Chegada: 566.44Km
# - Cuiabá                              | Autonimia na Chegada: 382.89Km
#   (Destino Final da Rota)

# %%
print("\nMapa com todas as cidades da amostra:")
m_todos = folium.Map([-14.5931291,-56.6985808], zoom_start=4)
marker_cluster_todos = MarkerCluster().add_to(m_todos)

for index_df, row_df in tqdm(df.iterrows(), total=len(df)):
  lat_val = row_df['lat']
  lon_val = row_df['lon']
  text_val = row_df['cidade']
  folium.Marker([lat_val, lon_val], popup=text_val).add_to(marker_cluster_todos)

display(m_todos)
# Out:
# Mapa com todas as cidades da amostra:
# 100%|██████████| 318/318 [00:00<00:00, 8606.09it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1bdf4a7f143dc6ac370a9be4e4b143fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1bdf4a7f143dc6ac370a9be4e4b143fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1bdf4a7f143dc6ac370a9be4e4b143fa = L.map(
#                 &quot;map_1bdf4a7f143dc6ac370a9be4e4b143fa&quot;,
#                 {
#                     center: [-14.5931291, -56.6985808],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af125fa9abaecd20ef5a48c876c65e2b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_af125fa9abaecd20ef5a48c876c65e2b.addTo(map_1bdf4a7f143dc6ac370a9be4e4b143fa);
#
#
#             var marker_cluster_86cb26c61f71320135858596081cd27f = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_b106d061797cc68990c2b20c9ffc419f = L.marker(
#                 [-23.468506, -46.531084],
#                 {
# }
#             ).addTo(marker_cluster_86cb26c61f71320135858596081cd27f);
#
#
#         var popup_5a63522595e9ff625998d8f4bc2baba6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6504982d87f86a878f544b35ece2390a = $(`&lt;div id=&quot;html_6504982d87f86a878f544b35ece2390a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Concessionária de carros de luxo fica completamente embaixo d&#x27;água em Guarulhos, na Grande SP; funcionários falam em prejuízos milionários - G1&lt;/div&gt;`)[0];
#                 popup_5a63522595e9ff625998d8f4bc2baba6.setContent(html_6504982d87f86a878f544b35ece2390a);
#
#
#
#         marker_b106d061797cc68990c2b20c9ffc419f.bindPopup(popup_5a63522595e9ff625998d8f4bc2baba6)
#         ;
#
#
#
#
#             var marker_ee048546b5e1d50c299dd98ba18cd462 = L.marker(
#                 [-5.352606, -49.142025],
#                 {
# }
#             ).addTo(marker_cluster_86cb26c61f71320135858596081cd27f);
#
#
#         var popup_2e518811156b2c368929db402c27f329 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01008d0ef7750960ac02d4a2653f8603 = $(`&lt;div id=&quot;html_01008d0ef7750960ac02d4a2653f8603&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Enchentes em 3 cidades do Pará deixam famílias desabrigadas; Exército é acionado para prestar apoio em Marabá - G1&lt;/div&gt;`)[0];
#                 popup_2e518811156b2c368929db402c27f329.setContent(html_01008d0ef7750960ac02d4a2653f8603);
#
#
#
#         marker_ee048546b5e1d50c299dd98ba18cd462.bindPopup(popup_2e518811156b2c368929db402c27f329)
#         ;
#
#
#
#
#             var marker_fe150c89bcb29068e8f0143487aa5139 = L.marker(
#                 [-26.991819, -48.634617],
#                 {
# }
#             ).addTo(marker_cluster_86cb26c61f71320135858596081cd27f);
#
#
#         var popup_061351f81a4892579f8749c756825b3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77ccac134520080a58abaf65fa38293b = $(`&lt;div id=&quot;html_77ccac134520080a58abaf65fa38293b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Veja imagens dos alagamentos em Balneário Camboriú - CNN Brasil&lt;/div&gt;`)[0];
#                 popup_061351f81a4892579f8749c756825b3e.setContent(html_77ccac134520080a58abaf65fa38293b);
#
#
#
#         marker_fe150c89bcb29068e8f0143487aa5139.bindPopup(popup_061351f81a4892579f8749c756825b3e)
#         ;
#
#
#
#
#             var marker_ed8316bf1967d0fe490c27640c58baf2 = L.marker(
#                 [-7.828372, -34.910583],
#                 {
# }
#             ).addTo(marker_cluster_86cb26c61f71320135858596081cd27f);
#
#
#         var popup_5bd02c0c9560fa610681ff98e595eb17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e54b1c2ace22a0e58fe4e76f18846f7 = $(`&lt;div id=&quot;html_4e54b1c2ace22a0e58fe4e76f18846f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Prefeita de Igarassu fala sobre situação do município a
